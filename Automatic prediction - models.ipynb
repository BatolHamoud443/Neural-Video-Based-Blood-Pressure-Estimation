# %%
# installing 3DDFA_V2 library (It includes a face detector Faceboxes)
! git clone https://github.com/cleardusk/3DDFA_V2.git
# Out:
# Cloning into '3DDFA_V2'...
# remote: Enumerating objects: 706, done.
# remote: Total 706 (delta 0), reused 0 (delta 0), pack-reused 706
# Receiving objects: 100% (706/706), 74.78 MiB | 35.30 MiB/s, done.
# Resolving deltas: 100% (366/366), done.

# %%
#Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd 3DDFA_V2
# !sh ./build.sh
# Out:
# /content/3DDFA_V2
# running build_ext
# cythoning nms/cpu_nms.pyx to nms/cpu_nms.c
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/3DDFA_V2/FaceBoxes/utils/nms/cpu_nms.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'nms.cpu_nms' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/nms
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c nms/cpu_nms.c -o build/temp.linux-x86_64-3.7/nms/cpu_nms.o -Wno-cpp -Wno-unused-function
# nms/cpu_nms.c: In function ‘__pyx_pf_3nms_7cpu_nms_2cpu_soft_nms’:
# nms/cpu_nms.c:3542:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#        __pyx_t_8 = ((__pyx_v_pos < __pyx_v_N) != 0);
#                                  ^
# nms/cpu_nms.c:4053:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#        __pyx_t_8 = ((__pyx_v_pos < __pyx_v_N) != 0);
#                                  ^
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/nms/cpu_nms.o -o /content/3DDFA_V2/FaceBoxes/utils/nms/cpu_nms.cpython-37m-x86_64-linux-gnu.so
# running build_ext
# cythoning lib/rasterize.pyx to lib/rasterize.cpp
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/3DDFA_V2/Sim3DR/lib/rasterize.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'Sim3DR_Cython' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/lib
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c lib/rasterize.cpp -o build/temp.linux-x86_64-3.7/lib/rasterize.o -std=c++11
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1969:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from lib/rasterize.cpp:760:
# /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c lib/rasterize_kernel.cpp -o build/temp.linux-x86_64-3.7/lib/rasterize_kernel.o -std=c++11
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/lib/rasterize.o build/temp.linux-x86_64-3.7/lib/rasterize_kernel.o -o /content/3DDFA_V2/Sim3DR/Sim3DR_Cython.cpython-37m-x86_64-linux-gnu.so

# %%
#importing librabies
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from pathlib import Path
import os.path
import glob
import os
from PIL import Image
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import itertools
from keras.layers import Flatten,Dense,BatchNormalization,Activation,Dropout, GlobalAveragePooling2D
import yaml
import os
import sys
import argparse
import imageio
from tqdm import tqdm
import yaml
from FaceBoxes import FaceBoxes
from TDDFA import TDDFA
from utils.render import render
from utils.functions import cv_draw_landmark, get_suffix

# %%
cfg = yaml.load(open('configs/mb1_120x120.yml'), Loader=yaml.SafeLoader)
onnx_flag = True
if onnx_flag:
    # !pip install onnxruntime
    
    import os
    os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
    os.environ['OMP_NUM_THREADS'] = '4'
    from FaceBoxes.FaceBoxes_ONNX import FaceBoxes_ONNX
    from TDDFA_ONNX import TDDFA_ONNX

    face_boxes = FaceBoxes_ONNX()
    tddfa = TDDFA_ONNX(**cfg)
else:
    face_boxes = FaceBoxes()
    tddfa = TDDFA(gpu_mode=False, **cfg)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting onnxruntime
#   Downloading onnxruntime-1.13.1-cp37-cp37m-manylinux_2_27_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 4.8 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (3.19.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (21.3)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.5 MB/s
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (1.7.1)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (1.21.6)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (1.12)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->onnxruntime) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->onnxruntime) (1.2.1)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.13.1
# /usr/local/lib/python3.7/dist-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input input
#   key
# /usr/local/lib/python3.7/dist-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input output
#   key
# Convert /content/3DDFA_V2/FaceBoxes/weights/FaceBoxesProd.pth to /content/3DDFA_V2/FaceBoxes/weights/FaceBoxesProd.onnx done.
# /usr/local/lib/python3.7/dist-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input alpha_shp
#   key
# /usr/local/lib/python3.7/dist-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input alpha_exp
#   key
# Convert configs/bfm_noneck_v3.pkl to configs/bfm_noneck_v3.onnx done.
# weights/mb1_120x120.onnx does not exist, try to convert the `.pth` version to `.onnx` online
# Convert weights/mb1_120x120.pth to weights/mb1_120x120.onnx done.

# %%
def fill(im,points):
    filler = cv2.convexHull(points)
    im=cv2.fillConvexPoly(im,filler , (0,0,0))
    return im

#cropping the face
def image_preprocess(frame):
    frame_bgr = frame[..., ::-1]
    boxes = face_boxes(frame_bgr)
    if boxes !=[]:
        box = boxes[0]
        boxes = [boxes[0]]
        fram1 = frame.copy()
        param_lst, roi_box_lst = tddfa(frame_bgr, boxes)
        ver = tddfa.recon_vers(param_lst, roi_box_lst, dense_flag=False)[0]
        param_lst, roi_box_lst = tddfa(frame_bgr, [ver], crop_policy='landmark')
        ver = tddfa.recon_vers(param_lst, roi_box_lst, dense_flag=False)[0]
        lst = [[round(ver[0][i]),round(ver[1][i])] for i in range(len(ver[0]))]
        lst.append([round(ver[0][17]), round(ver[1][17]+2*(ver[1][17]-ver[1][36]))])
        lst.append([round(ver[0][26]), round(ver[1][26]+2*(ver[1][26]-ver[1][45]))])
        lst = np.array(lst,dtype='int')
        frame = fill(frame,lst)
        final = fram1 -frame
        final  = final[...,::-1]
        final = final[round(box[1]):round(box[3]), round(box[0]):round(box[2])]
        left = []
        left.append(lst[1][1])
        left.append(lst[3][1])
        left.append(lst[3][0])
        left.append(int((lst[13][0]-lst[3][0])/3))

        ######
        right = []
        right.append(lst[15][1])
        right.append(lst[13][1])
        right.append(int((lst[13][0]-lst[3][0])/3))
        right.append(lst[13][0])
        
        print(right)

        frame = fill(frame,lst)
        final = fram1 -frame
        final  = final[...,::-1]
        final = final[round(box[1]):round(box[3]), round(box[0]):round(box[2])]
        print(left)
        print(right)
        return left, right
    else:
        return frame

# %%
import os, sys
from FaceBoxes.FaceBoxes_ONNX import *

# %%
face_boxes = FaceBoxes_ONNX(timer_flag=True)

# %%
#preprocess the input
def load_dataset(img, m):
    if img.mode == 'RGBA':
      alpha = img.split()[3]
      bgmask = alpha.point(lambda x: 255-x)
      img = img.convert('RGB')
      img.paste((255,255,255), None, bgmask)
    img = img.resize((m, m), Image.ANTIALIAS)
    img = np.array(img)
    img = np.flipud(img)
    means = img.mean(axis=(0,1), dtype='float64')
    stds = img.std(axis=(0,1), dtype='float64')
    img = (img - means) / stds            
    return img

# %%
#upload the models
import json
from tensorflow import keras

json_file = open('/content/gdrive/MyDrive/Models/model_1_sys.json', 'r')
#instead of model_1_sys we can use (model_2_sys, model_3_sys, model_1_dias, model_2_dias, model_3_dias)
loaded_model_json = json_file.read()
json_file.close()
loaded_model =  keras.models.model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/content/gdrive/MyDrive/Models/model_1_sys.hdf5")
#instead of model_1_sys we can use (model_2_sys, model_3_sys, model_1_dias, model_2_dias, model_3_dias)
loaded_model.compile(optimizer='adam',
    loss='mse',
    metrics = ['mae']
)

# %%
#make predictions
def predicting(left, right):

  pred= loaded_model.predict(x=[left, right])
  return pred.tolist()

# %%
#path to the test videos
files_seq = []
testing_folder ='/content/gdrive/MyDrive/Videos'
for root, subdirs, files in os.walk(testing_folder):
    for d in files:
      files_seq.append(str(d))

# %%
#main function to get the predictions
def p(video_name):
  file_path = '/content/gdrive/MyDrive/Videos/'+str(video_name)
  cap = cv2.VideoCapture(file_path)
  currentframe = 0
  left = []
  right = []  
  bp = []
  while(True):
    success, frame = cap.read()
  
    if success:               
        boxes = face_boxes(frame)                   
        if len(boxes)==0:
          img1 = frame[int(3*frame.shape[0]/7):int(4*frame.shape[0]/7), int(1*frame.shape[1]/5):int(2*frame.shape[1]/5)]
          img1 = Image.fromarray(img1)
          img1 = load_dataset(img1, 32)
          left.append(img1)
          img2 = frame[int(3*frame.shape[0]/7):int(4*frame.shape[0]/7), int(3*frame.shape[1]/5):int(4*frame.shape[1]/5)]
          img2 = Image.fromarray(img2)
          img2 = load_dataset(img2, 32)
          right.append(img2)
          currentframe +=1

        else:
          for i in range(len(boxes)):
            box = np.array(boxes[i],dtype=int)
            orig_image = frame[box[1]:box[3], box[0]:box[2]]
            cv2.rectangle(frame, (box[0], box[1]), (box[2], box[3]), (255, 255, 0), 4)
            orig_image =orig_image[...,::-1]
            img1 = orig_image[int(orig_image.shape[0]/2):int(3*orig_image.shape[0]/4), int(orig_image.shape[1]/8):int(orig_image.shape[1]/3)]
            img1 = Image.fromarray(img1)
            img1 = load_dataset(img1, 32)
            left.append(img1)
            img2 = orig_image[int(orig_image.shape[0]/2):int(3*orig_image.shape[0]/4), int(2*orig_image.shape[1]/3):int(7*orig_image.shape[1]/8)]
            img2 = Image.fromarray(img2)
            img2 = load_dataset(img2, 32)
            right.append(img2)
            currentframe +=1

        
        if currentframe == 25:
          left = np.array(left , dtype= np.uint8).reshape(-1,25,32,32,3)
          right = np.array(right, dtype= np.uint8).reshape(-1,25,32,32,3)
          bp = np.append(bp, predicting(left, right))
          currentframe = 0
          left = []
          right = []   
    else:
      break
    bp = np.array(bp).reshape(-1,1)
    bp_values_1 = pd.Series(bp[:,0], name='S-BP').astype(float) #instead of 'S-BP' we write 'D-BP' when predicting DBP
    bp_values_1.to_csv('/content/gdrive/MyDrive/Output/model_1_sys/CSVs/'+ str(video_name)[:-4]+'.csv', index = False)

# %%
for i in files_seq:
  p(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0072s
# 1/1 [==============================] - 0s 297ms/step
# Detection: 1/1 forward_pass_time: 0.0255s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0097s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0217s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0255s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0085s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0222s misc: 0.0076s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0261s misc: 0.0122s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0303s misc: 0.0087s
# Detection: 1/1 forward_pass_time: 0.0196s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0266s misc: 0.0093s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0069s
# 1/1 [==============================] - 0s 288ms/step
# Detection: 1/1 forward_pass_time: 0.0266s misc: 0.0114s
# Detection: 1/1 forward_pass_time: 0.0293s misc: 0.0096s
# Detection: 1/1 forward_pass_time: 0.0255s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0259s misc: 0.0127s
# Detection: 1/1 forward_pass_time: 0.0270s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0364s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0397s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0277s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0280s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0312s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0325s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0302s misc: 0.0113s
# Detection: 1/1 forward_pass_time: 0.0278s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0318s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0295s misc: 0.0130s
# Detection: 1/1 forward_pass_time: 0.0275s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0106s
# Detection: 1/1 forward_pass_time: 0.0279s misc: 0.0111s
# Detection: 1/1 forward_pass_time: 0.0273s misc: 0.0106s
# Detection: 1/1 forward_pass_time: 0.0383s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0391s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0274s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0418s misc: 0.0141s
# Detection: 1/1 forward_pass_time: 0.0304s misc: 0.0133s
# 1/1 [==============================] - 0s 428ms/step
# Detection: 1/1 forward_pass_time: 0.0274s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0363s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0478s misc: 0.0116s
# Detection: 1/1 forward_pass_time: 0.0284s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0110s
# Detection: 1/1 forward_pass_time: 0.0400s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0384s misc: 0.0113s
# Detection: 1/1 forward_pass_time: 0.0278s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0367s misc: 0.0130s
# Detection: 1/1 forward_pass_time: 0.0279s misc: 0.0106s
# Detection: 1/1 forward_pass_time: 0.0273s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0288s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0274s misc: 0.0106s
# Detection: 1/1 forward_pass_time: 0.0277s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0414s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0295s misc: 0.0107s
# Detection: 1/1 forward_pass_time: 0.0294s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0358s misc: 0.0128s
# Detection: 1/1 forward_pass_time: 0.0317s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0268s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0289s misc: 0.0106s
# Detection: 1/1 forward_pass_time: 0.0324s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0283s misc: 0.0112s
# Detection: 1/1 forward_pass_time: 0.0288s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0275s misc: 0.0108s
# 1/1 [==============================] - 0s 397ms/step
# Detection: 1/1 forward_pass_time: 0.0269s misc: 0.0130s
# Detection: 1/1 forward_pass_time: 0.0207s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0090s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0230s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0271s misc: 0.0072s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0294s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0199s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0284s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0270s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0259s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0071s
# 1/1 [==============================] - 0s 242ms/step
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0074s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0267s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0229s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0211s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0245s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0267s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0216s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0057s
# 1/1 [==============================] - 0s 228ms/step
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0090s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0177s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0259s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0094s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0254s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0283s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0092s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0315s misc: 0.0061s
# 1/1 [==============================] - 0s 232ms/step
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0217s misc: 0.0086s
# Detection: 1/1 forward_pass_time: 0.0205s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0264s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0097s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0110s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0218s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0219s misc: 0.0125s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# 1/1 [==============================] - 0s 253ms/step
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0072s
# Detection: 1/1 forward_pass_time: 0.0268s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0086s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0089s
# Detection: 1/1 forward_pass_time: 0.0273s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0207s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0245s misc: 0.0095s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0243s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0061s
# 1/1 [==============================] - 0s 244ms/step
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0279s misc: 0.0074s
# Detection: 1/1 forward_pass_time: 0.0256s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0218s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0079s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0087s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0232s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0076s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0096s
# 1/1 [==============================] - 0s 239ms/step
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0200s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0266s misc: 0.0090s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0212s misc: 0.0094s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0294s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0285s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0230s misc: 0.0059s
# 1/1 [==============================] - 0s 236ms/step
# Detection: 1/1 forward_pass_time: 0.0298s misc: 0.0081s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0091s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0262s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0284s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0087s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0200s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0212s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0177s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0229s misc: 0.0059s
# 1/1 [==============================] - 0s 257ms/step
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0280s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0227s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0087s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0222s misc: 0.0093s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0205s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0087s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0059s
# 1/1 [==============================] - 0s 243ms/step
# Detection: 1/1 forward_pass_time: 0.0283s misc: 0.0118s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0094s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0240s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0266s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0218s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0272s misc: 0.0077s
# Detection: 1/1 forward_pass_time: 0.0292s misc: 0.0097s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0229s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0232s misc: 0.0060s
# 1/1 [==============================] - 0s 239ms/step
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0082s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0305s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0255s misc: 0.0079s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0243s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0267s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0249s misc: 0.0058s
# 1/1 [==============================] - 0s 240ms/step
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0265s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0256s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0217s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0093s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0222s misc: 0.0083s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0118s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0101s
# 1/1 [==============================] - 0s 269ms/step
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0121s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0089s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0092s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0211s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0272s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0325s misc: 0.0096s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0086s
# Detection: 1/1 forward_pass_time: 0.0227s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0112s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0218s misc: 0.0076s
# 1/1 [==============================] - 0s 234ms/step
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0207s misc: 0.0109s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0240s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0060s
# 1/1 [==============================] - 0s 234ms/step
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0075s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0263s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0304s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0205s misc: 0.0087s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0243s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0240s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0175s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0059s
# 1/1 [==============================] - 0s 249ms/step
# Detection: 1/1 forward_pass_time: 0.0278s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0247s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0238s misc: 0.0083s
# Detection: 1/1 forward_pass_time: 0.0230s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0096s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0205s misc: 0.0113s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0094s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0119s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0063s
# 1/1 [==============================] - 0s 264ms/step
# Detection: 1/1 forward_pass_time: 0.0273s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0224s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0252s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0293s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0293s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0083s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0263s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0305s misc: 0.0059s
# 1/1 [==============================] - 0s 250ms/step
# Detection: 1/1 forward_pass_time: 0.0247s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0310s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0270s misc: 0.0073s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0243s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0075s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0223s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0222s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0222s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0336s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0199s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0230s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0113s
# 1/1 [==============================] - 0s 251ms/step
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0275s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0283s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0219s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0089s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0277s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0227s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0207s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0059s
# 1/1 [==============================] - 0s 236ms/step
# Detection: 1/1 forward_pass_time: 0.0254s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0223s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0273s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0285s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0283s misc: 0.0075s
# 1/1 [==============================] - 0s 263ms/step
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0115s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0227s misc: 0.0140s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0258s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0273s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0229s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0268s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0298s misc: 0.0058s
# 1/1 [==============================] - 0s 239ms/step
# Detection: 1/1 forward_pass_time: 0.0199s misc: 0.0132s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0238s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0077s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0367s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0080s
# 1/1 [==============================] - 0s 252ms/step
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0247s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0284s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0223s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0072s
# Detection: 1/1 forward_pass_time: 0.0258s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0115s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0077s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0352s misc: 0.0096s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# 1/1 [==============================] - 0s 256ms/step
# Detection: 1/1 forward_pass_time: 0.0306s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0261s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0257s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0223s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0268s misc: 0.0075s
# Detection: 1/1 forward_pass_time: 0.0240s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0216s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0213s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0277s misc: 0.0059s
# 1/1 [==============================] - 0s 257ms/step
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0275s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0123s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0242s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0218s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0256s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0255s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0059s
# 1/1 [==============================] - 0s 238ms/step
# Detection: 1/1 forward_pass_time: 0.0296s misc: 0.0125s
# Detection: 1/1 forward_pass_time: 0.0223s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0222s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0261s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0265s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0304s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0249s misc: 0.0077s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0286s misc: 0.0113s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0249s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# 1/1 [==============================] - 0s 242ms/step
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0311s misc: 0.0116s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0199s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0082s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0282s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0219s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0280s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0193s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0058s
# 1/1 [==============================] - 0s 251ms/step
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0196s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0196s misc: 0.0086s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0243s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0278s misc: 0.0166s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0076s
# Detection: 1/1 forward_pass_time: 0.0212s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0217s misc: 0.0096s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0229s misc: 0.0082s
# 1/1 [==============================] - 0s 253ms/step
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0293s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0264s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0207s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0211s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0089s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0290s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0235s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0075s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0213s misc: 0.0123s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0075s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0086s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0118s
# 1/1 [==============================] - 0s 238ms/step
# Detection: 1/1 forward_pass_time: 0.0285s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0250s misc: 0.0072s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0095s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0219s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0094s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0225s misc: 0.0077s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0308s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0068s
# ...
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0060s
# 1/1 [==============================] - 0s 236ms/step
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0249s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0262s misc: 0.0082s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0230s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0254s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0257s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0210s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0230s misc: 0.0072s
# 1/1 [==============================] - 0s 245ms/step
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0097s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0086s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0229s misc: 0.0111s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0227s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0269s misc: 0.0075s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0205s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0232s misc: 0.0059s
# 1/1 [==============================] - 0s 300ms/step
# Detection: 1/1 forward_pass_time: 0.0434s misc: 0.0125s
# Detection: 1/1 forward_pass_time: 0.0213s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0282s misc: 0.0121s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0126s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0288s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0072s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0072s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0205s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0211s misc: 0.0077s
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0217s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0269s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0288s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0073s
# 1/1 [==============================] - 0s 306ms/step
# Detection: 1/1 forward_pass_time: 0.0342s misc: 0.0136s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0073s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0080s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0200s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0265s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0203s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0354s misc: 0.0133s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0082s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0223s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0209s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0224s misc: 0.0103s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0220s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0200s misc: 0.0067s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0256s misc: 0.0067s
# 1/1 [==============================] - 0s 294ms/step
# Detection: 1/1 forward_pass_time: 0.0263s misc: 0.0111s
# Detection: 1/1 forward_pass_time: 0.0277s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0266s misc: 0.0073s
# Detection: 1/1 forward_pass_time: 0.0313s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0291s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0261s misc: 0.0137s
# Detection: 1/1 forward_pass_time: 0.0224s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0224s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0208s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0264s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0070s
# Detection: 1/1 forward_pass_time: 0.0211s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0212s misc: 0.0094s
# Detection: 1/1 forward_pass_time: 0.0200s misc: 0.0085s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0074s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0218s misc: 0.0068s
# Detection: 1/1 forward_pass_time: 0.0207s misc: 0.0069s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0092s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0263s misc: 0.0079s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0268s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0092s
# 1/1 [==============================] - 0s 417ms/step
# Detection: 1/1 forward_pass_time: 0.0237s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0278s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0272s misc: 0.0111s
# Detection: 1/1 forward_pass_time: 0.0278s misc: 0.0128s
# Detection: 1/1 forward_pass_time: 0.0267s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0270s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0286s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0272s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0271s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0290s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0283s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0271s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0441s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0264s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0271s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0432s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0269s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0276s misc: 0.0110s
# Detection: 1/1 forward_pass_time: 0.0263s misc: 0.0105s
# Detection: 1/1 forward_pass_time: 0.0265s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0339s misc: 0.0108s
# Detection: 1/1 forward_pass_time: 0.0288s misc: 0.0097s
# Detection: 1/1 forward_pass_time: 0.0264s misc: 0.0097s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0095s
# 1/1 [==============================] - 0s 318ms/step
# Detection: 1/1 forward_pass_time: 0.0270s misc: 0.0084s
# Detection: 1/1 forward_pass_time: 0.0201s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0195s misc: 0.0104s
# Detection: 1/1 forward_pass_time: 0.0178s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0234s misc: 0.0085s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0212s misc: 0.0092s
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0347s misc: 0.0091s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0202s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0259s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0090s
# 1/1 [==============================] - 0s 255ms/step
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0231s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0287s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0064s
# Detection: 1/1 forward_pass_time: 0.0277s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0191s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0253s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0228s misc: 0.0102s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0272s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0215s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0096s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0255s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0058s
# 1/1 [==============================] - 0s 251ms/step
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0313s misc: 0.0099s
# Detection: 1/1 forward_pass_time: 0.0213s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0292s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0189s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0272s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0204s misc: 0.0081s
# Detection: 1/1 forward_pass_time: 0.0197s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0194s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0254s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0251s misc: 0.0098s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0233s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0190s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0100s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0246s misc: 0.0066s
# Detection: 1/1 forward_pass_time: 0.0187s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0221s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0192s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0058s
# 1/1 [==============================] - 0s 267ms/step
# Detection: 1/1 forward_pass_time: 0.0185s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0206s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0226s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0326s misc: 0.0078s
# Detection: 1/1 forward_pass_time: 0.0196s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0211s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0241s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0182s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0248s misc: 0.0101s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0257s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0240s misc: 0.0074s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0239s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0214s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0198s misc: 0.0063s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0062s
# Detection: 1/1 forward_pass_time: 0.0254s misc: 0.0058s
# 1/1 [==============================] - 0s 240ms/step
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0180s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0061s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0257s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0257s misc: 0.0057s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0279s misc: 0.0071s
# Detection: 1/1 forward_pass_time: 0.0199s misc: 0.0065s
# Detection: 1/1 forward_pass_time: 0.0299s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0188s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0183s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0199s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0179s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0184s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0060s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0085s
# Detection: 1/1 forward_pass_time: 0.0236s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0244s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0181s misc: 0.0058s
# Detection: 1/1 forward_pass_time: 0.0263s misc: 0.0059s
# Detection: 1/1 forward_pass_time: 0.0186s misc: 0.0058s
